# %% [markdown]
# # Boilerplate (imports)

# %%
import os
import sys 
import cobra
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
import math
import torch
import scipy
import os.path
import functools
import timeit
import pickle
import gurobipy # make sure some solver backend is available for iMAT/FBA/MoMA
from projection_methods import MoMAWrapper, FBApro, FBAWrapper, IMATWrapper

# %% [markdown]
# ### Solver configuration

# %%
# Set up gurobi or other optimizer license file if needed
# os.environ['GRB_LICENSE_FILE'] = "/path/to/your/gurobi.lic"

# %% [markdown]
# # Helpers: consistent method ordering and checkpointing

# %%
# Canonical method order used throughout all figures
METHOD_ORDER = ["FBAproBasic", "FBAproPartial", "FBAproFixed", "FBAproFull",
                "FBA", "MoMA", "iMAT"]

def normalize_method_name(name):
    """Normalize method names from internal naming to canonical display names."""
    name = name.replace("LowMid", "Partial").replace("HighMid", "Fixed")
    if name == "FBApro":
        return "FBAproBasic"
    if name == "FBAproPartialFixed":
        return "FBAproFull"
    return name

def set_method_order(df, col='method'):
    """Set canonical categorical ordering on the method column."""
    present = [m for m in METHOD_ORDER if m in df[col].unique()]
    df[col] = pd.Categorical(df[col], categories=present, ordered=True)
    return df

def save_checkpoint(obj, path):
    with open(path, 'wb') as f:
        pickle.dump(obj, f)
    print(f"  [checkpoint saved: {path}]")

def load_checkpoint(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# # Test with iid noise to steady-state data

# %% [markdown]
# ## Generate data

# %%
# %%time

reaction_size_cutoff = 6000 # > 10600 for all models in model_organism_* variables
n_samples_per_graph = 50
base_noise_power = 1.0
base_frac_known_reactions = 0.02
base_frac_unknown_reactions = 0.85
device = torch.device("cuda")

models = list()
As = list()
ss_bases = list()
ss_fluxes = list()
perturbed_fluxes = list()
names = list()
known_masks = list()
unknown_masks = list()

data_dir = 'synthetic_data_experiment_files/data'
caching_dir = 'synthetic_data_experiment_files/caching'
export_path = 'synthetic_data_experiment_files/outputs'

model_organism_model_names = ['e_coli_core', 'iML1515', 'iND750', 'iMM1415', 'RECON1', 'Recon3D']
model_organism_organisms = ['e_coli_core', 'e_coli_K_12', 'yeast', 'mouse', 'human_1', 'human_3d']
model_name_to_organism = {k: v for k, v in zip(model_organism_model_names, model_organism_organisms)}

for i, model_filename in enumerate(os.listdir(data_dir)):
    name = model_filename.split('.')[0]
    if name not in model_organism_model_names:
        continue
    model = cobra.io.read_sbml_model(os.path.join(data_dir, model_filename))
    if len(model.reactions) > reaction_size_cutoff:
        continue    
    models.append(model)
    if os.path.exists(os.path.join(caching_dir, name + "_cached_A.npy")):
        print(i, name, "(cached)")
        A = np.load(os.path.join(caching_dir, name + "_cached_A.npy"))
        basis = np.load(os.path.join(caching_dir, name + "_cached_basis.npy")) 
    else:
        print(i, name)
        A = cobra.util.create_stoichiometric_matrix(model)
        basis = scipy.linalg.null_space(A)
        np.save(os.path.join(caching_dir, name + "_cached_A"), A)
        np.save(os.path.join(caching_dir, name + "_cached_basis"), basis) 
        
    print("Model shape: {}".format(A.shape))
    As.append(A)
    names.append(model_filename.split(".")[0])
    print("ss basis shape:", basis.shape)
    ss_bases.append(basis)

    coefficients = np.random.random(size=(basis.shape[1], n_samples_per_graph))
    steady_states_sampled_fluxes = (basis @ coefficients).transpose()
    ss_fluxes.append(steady_states_sampled_fluxes)
    
    known_indices = np.array(sorted(np.random.choice(np.array(list(range(A.shape[1]))), size=math.ceil(base_frac_known_reactions * A.shape[1]), replace=False)))
    other_indices = list(set(range(A.shape[1])) - set(known_indices))
    unknown_indices = np.array(sorted(np.random.choice(np.array(other_indices), size=math.ceil(base_frac_unknown_reactions * A.shape[1]), replace=False)))
        
    known_mask = np.zeros(A.shape[1], dtype=bool)
    known_mask[known_indices] = True    
    known_masks.append(known_mask)

    unknown_mask = np.zeros(A.shape[1], dtype=bool)
    unknown_mask[unknown_indices] = True
    unknown_masks.append(unknown_mask)

    # Multiplicative noise on non-known reactions; zero out unknown reactions
    noised_steady_states = [ss * np.where(known_mask, 1, (1 + base_noise_power * 2 * (np.random.random(size=ss.shape) - 0.5))) for ss in steady_states_sampled_fluxes]
    noised_steady_states = [ns * np.where(unknown_mask, 0, 1) for ns in noised_steady_states]
    noised_steady_states = np.array(noised_steady_states)
    perturbed_fluxes.append(noised_steady_states)
    
ys = [torch.tensor(y.astype(np.float64)) for y in ss_fluxes]
Xs = [torch.tensor(X.astype(np.float64)) for X in perturbed_fluxes]

n_graphs = len(As)
# Out:
# Set parameter LicenseID to value 197246
# Set parameter GURO_PAR_SPECIAL
# Set parameter TokenServer to value "license.rc.princeton.edu"
# 1 e_coli_core (cached)
# Model shape: (72, 95)
# ss basis shape: (95, 28)
# No objective coefficients in model. Unclear what should be optimized
# 2 iMM1415 (cached)
# Model shape: (2775, 3726)
# ss basis shape: (3726, 1041)
# 3 iND750 (cached)
# Model shape: (1059, 1266)
# ss basis shape: (1266, 284)
# 4 RECON1 (cached)
# Model shape: (2766, 3741)
# ss basis shape: (3741, 1067)
# 6 iML1515 (cached)
# Model shape: (1877, 2712)
# ss basis shape: (2712, 867)
# CPU times: user 24.1 s, sys: 726 ms, total: 24.8 s
# Wall time: 25.6 s

# %% [markdown]
# ### (Commented out) Open up exchange bounds

# %%
# for model in models:
#     for r in model.reactions:
#         bounds = [r.bounds[0], r.bounds[1]]
#         if bounds[0] < 0:
#             bounds[0] = -1000
#         if bounds[1] > 0:
#             bounds[1] = 1000
#         if bounds == (0, 0):
#             bounds = -1000, 1000
#         r.bounds = bounds

# %% [markdown]
# ### Generate approximate bounds

# %%
# Generate approximate bounds from ground truth Y
ls = []
us = []
epsilon = 1e-5
for model_index, model, X, Y, known_mask, unknown_mask in zip(list(range(len(models))), models, Xs, ys, known_masks, unknown_masks):
    print(model_index)
    l = np.zeros(shape=(X.shape[0], X.shape[1]))
    u = np.zeros(shape=(X.shape[0], X.shape[1]))
    for i, sample in enumerate(Y):
        sign = torch.sign(sample)
        noisy_mask = ~known_mask & ~unknown_mask
        l[i, :] = (1 - base_noise_power * sign * noisy_mask) * sample - epsilon  
        u[i, :] = (1 + base_noise_power * sign * noisy_mask) * sample + epsilon  
    for j, r in enumerate(model.reactions):
        if unknown_mask[j]:
            l[:, j] = r.bounds[0]
            u[:, j] = r.bounds[1]
        
    l = torch.tensor(l, dtype=torch.double, device=device)
    u = torch.tensor(u, dtype=torch.double, device=device)
    ls.append(l)
    us.append(u)
# Out:
# 0
# /tmp/ipykernel_3957302/1576260736.py:12: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   l[i, :] = (1 - base_noise_power * sign * noisy_mask) * sample - epsilon
# /tmp/ipykernel_3957302/1576260736.py:13: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   u[i, :] = (1 + base_noise_power * sign * noisy_mask) * sample + epsilon
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Test runtime of projection vs FBA — single-sample, batch, and GPU

# %%
# %%time
n_timeit_nonsetup_repeats = 1

methods = [FBApro,
           FBAWrapper,
           IMATWrapper,
           MoMAWrapper]

method_names = []
records = []
assert torch.cuda.is_available(), "GPU is required for CPU vs GPU timing comparison. No CUDA device found."

for i in range(len(models)):
    print("model {}, size {}".format(i, len(models[i].reactions)))
    model = models[i]
    organism_name = model_name_to_organism[model.id]
    n_rxns = len(model.reactions)
    obj_coefs = {rxn.id: rxn.objective_coefficient for rxn in model.reactions if rxn.objective_coefficient != 0}
    print(obj_coefs)
    print([r.id for r in model.reactions if 'biomass' in r.id.lower()])
    if len(obj_coefs) == 0:
        growth_related_reactions = [r.id for r in model.reactions if 'biomass' in r.id.lower()]
        assert len(growth_related_reactions) == 1
        obj_coefs = {growth_related_reactions[0]: 1}
    assert len(obj_coefs) == 1 and all([v == 1 for k, v in obj_coefs.items()])
    objective_reaction_ids = obj_coefs.popitem()[0]

    A = As[i]
    basis = ss_bases[i]
    known_mask = known_masks[i]
    unknown_mask = unknown_masks[i]
    X = Xs[i].to(dtype=torch.double)
    y = ys[i].to(dtype=torch.double)
    l = ls[i].to(dtype=torch.double)
    u = us[i].to(dtype=torch.double)

    with model:
        for method in methods:
            partial_fixed_iterators = itertools.product([False, True], [False, True])
            for (is_partial, is_fixed) in partial_fixed_iterators:
                unknown_indices = [q for q in range(len(unknown_mask)) if unknown_mask[q]] if is_partial else []
                measured_indices = [q for q in range(len(known_mask)) if known_mask[q]] if is_fixed else []
                cur_records = []

                name_raw = None  # will be set from str(proj)

                # --- Setup timing (FBApro variants only) ---
                if method == FBApro:
                    timeit_results = timeit.repeat(
                        functools.partial(method, model=model, stoichiometric_matrix=A,
                                          unknown_indices=unknown_indices, measured_indices=measured_indices,
                                          steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                                          device=torch.device('cpu'), objective_id=objective_reaction_ids),
                        number=1, repeat=1)
                    # Get the name from an actual instantiation
                    proj_tmp = method(model=model, stoichiometric_matrix=A,
                                      unknown_indices=unknown_indices, measured_indices=measured_indices,
                                      steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                                      device=torch.device('cpu'), objective_id=objective_reaction_ids)
                    name_raw = str(proj_tmp)
                    name = normalize_method_name(name_raw)
                    del proj_tmp

                    for t in timeit_results:
                        cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                            'method': name + "_setup", 'batch': 1, 'device': 'CPU', 'time': t})

                    timeit_results = timeit.repeat(
                        functools.partial(method, model=model, stoichiometric_matrix=A,
                                          unknown_indices=unknown_indices, measured_indices=measured_indices,
                                          steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                                          device=torch.device('cuda'), objective_id=objective_reaction_ids),
                        number=1, repeat=1)
                    for t in timeit_results:
                        cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                            'method': name + "_setup", 'batch': 1, 'device': 'GPU', 'time': t})

                # --- CPU projection: per-sample timing ---
                proj = method(model=model, stoichiometric_matrix=A,
                              unknown_indices=unknown_indices, measured_indices=measured_indices,
                              steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                              device=torch.device('cpu'), objective_id=objective_reaction_ids)
                if name_raw is None:
                    name_raw = str(proj)
                    name = normalize_method_name(name_raw)

                if i == 0 and method == methods[0] and not is_partial and not is_fixed:
                    method_names = []  # reset on first model
                if len(method_names) < len(list(itertools.product([False, True], [False, True]))) * len(methods):
                    pass  # names tracked via normalize

                for sample in range(X.shape[0]):
                    if sample % 20 == 0:
                        print("  {} sample {}/{}".format(name, sample, X.shape[0]))
                    timeit_results = timeit.repeat(
                        functools.partial(proj.forward, X[[sample], :], l[[sample]], u[[sample]]),
                        number=1, repeat=n_timeit_nonsetup_repeats)
                    for t in timeit_results:
                        cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                            'method': name, 'batch': 1, 'device': 'CPU', 'time': t})

                # --- GPU per-sample timing (FBApro only) ---
                if method == FBApro:
                    gpu_proj = method(model=model, stoichiometric_matrix=A,
                                      unknown_indices=unknown_indices, measured_indices=measured_indices,
                                      steady_state_basis_matrix=basis, l_bounds=l.cuda(), u_bounds=u.cuda(),
                                      device=torch.device('cuda'), objective_id=objective_reaction_ids)
                    for sample in range(X.shape[0]):
                        if sample % 20 == 0:
                            print("  {} GPU sample {}/{}".format(name, sample, X.shape[0]))
                        timeit_results = timeit.repeat(
                            functools.partial(gpu_proj.forward, X[[sample], :].cuda(),
                                              l[[sample]].cuda(), u[[sample]].cuda()),
                            number=1, repeat=n_timeit_nonsetup_repeats)
                        for t in timeit_results:
                            cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                                'method': name, 'batch': 1, 'device': 'GPU', 'time': t})
                    del gpu_proj

                # --- Batch timing (FBApro only) ---
                if method == FBApro:
                    # CPU batch
                    proj_batch = method(model=model, stoichiometric_matrix=A,
                                        unknown_indices=unknown_indices, measured_indices=measured_indices,
                                        steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                                        device=torch.device('cpu'), objective_id=objective_reaction_ids)
                    timeit_results = [t / X.shape[0] for t in timeit.repeat(
                        functools.partial(proj_batch.forward, X, l, u),
                        number=1, repeat=n_timeit_nonsetup_repeats)]
                    for t in timeit_results:
                        cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                            'method': name, 'batch': X.shape[0], 'device': 'CPU', 'time': t})

                    # GPU batch
                    X_gpu = X.cuda()
                    l_gpu = l.cuda()
                    u_gpu = u.cuda()
                    proj_gpu = method(model=model, stoichiometric_matrix=A,
                                  unknown_indices=unknown_indices, measured_indices=measured_indices,
                                  steady_state_basis_matrix=basis, l_bounds=l_gpu, u_bounds=u_gpu,
                                  device=torch.device('cuda'), objective_id=objective_reaction_ids)
                    timeit_results = [t / X.shape[0] for t in timeit.repeat(
                        functools.partial(proj_gpu.forward, X_gpu, l_gpu, u_gpu),
                        number=1, repeat=n_timeit_nonsetup_repeats)]
                    for t in timeit_results:
                        cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                            'method': name, 'batch': X.shape[0], 'device': 'GPU', 'time': t})

                records.extend(cur_records)
                del proj

                if method != FBApro:
                    break

    # Checkpoint after each model
    save_checkpoint({'records': records}, os.path.join(caching_dir, 'timing_checkpoint.pkl'))

runtimes_df = pd.DataFrame(records)
# Normalize any remaining raw names
runtimes_df['method'] = runtimes_df['method'].apply(lambda m: normalize_method_name(m) if '_setup' not in m else normalize_method_name(m.replace('_setup', '')) + '_setup')
print("Done. {} records".format(len(records)))
# Out:
# model 0, size 95
# {'BIOMASS_Ecoli_core_w_GAM': 1.0}
# ['BIOMASS_Ecoli_core_w_GAM']
#   FBAproBasic sample 0/50
#   FBAproBasic sample 20/50
#   FBAproBasic sample 40/50
#   FBAproBasic GPU sample 0/50
#   FBAproBasic GPU sample 20/50
#   FBAproBasic GPU sample 40/50
# /home/abronner/FBApro/projection_methods.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('stoic', torch.tensor(stoichiometric_matrix, device=device, dtype=dtype),
#   FBAproFixed sample 0/50
#   FBAproFixed sample 20/50
#   FBAproFixed sample 40/50
#   FBAproFixed GPU sample 0/50
# ...
# Input - abs min: 0.00e+00, abs max: 7.39e-01, abs mean: 4.46e-02
# output - abs min: 3.44e-16, abs max: 9.87e-01, abs mean: 1.44e-01
# S * output - abs min: 1.10e-15, abs max: 1.03e+00, abs mean: 1.75e-01
# Suppressing further warnings.
# ...

# %% [markdown]
# ### Save runtime results

# %%
sns.set_style("whitegrid")
runtimes_df['organism_device_batch'] = runtimes_df['organism'] + ', ' + runtimes_df['device'] + ', ' + runtimes_df['batch'].astype(str)
runtimes_df['device_batch'] = runtimes_df['device'] + ', ' + runtimes_df['batch'].astype(str)

# %% [markdown]
# ## Runtime plots

# %%
os.makedirs(os.path.join(export_path, "figure_recreation_data"), exist_ok=True)
runtimes_df.to_csv(os.path.join(export_path, "figure_recreation_data", "runtimes_df"))

# %% [markdown]
# ### All methods, grouped by organism × device × batch

# %%
plt.figure(figsize=(18, 10))
filtered = runtimes_df.loc[~runtimes_df["method"].str.contains('setup')].copy()
filtered = set_method_order(filtered)
sns.barplot(data=filtered, x='organism_device_batch', y='time', hue='method')
plt.title("Runtime by Organism, Device, and Batch Size")
plt.ylabel("Time (seconds)")
plt.legend()
plt.yscale('log')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### All methods, grouped by device × batch

# %%
plt.figure(figsize=(18, 10))
filtered = runtimes_df.loc[~runtimes_df["method"].str.contains('setup')].copy()
filtered = set_method_order(filtered)
sns.barplot(data=filtered, x='device_batch', y='time', hue='method')
plt.title("Runtime by Device and Batch Size (all organisms)")
plt.ylabel("Time (seconds)")
plt.legend()
plt.yscale('log')
plt.tight_layout()
filename = "all_devices_timing_methods.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Batch runtime per organism (FBApro batch vs others single-sample)

# %%
runtimes_df['organism, #reactions'] = runtimes_df['organism'] + ", " + runtimes_df['reactions'].astype(str)
filter_mask = ~runtimes_df["method"].str.contains("FBApro|_setup", regex=True) | (runtimes_df["batch"] == n_samples_per_graph)
filtered = runtimes_df.loc[filter_mask].copy()
filtered = filtered.loc[~filtered['method'].str.contains('setup')]
filtered = set_method_order(filtered)

g = sns.catplot(data=filtered.sort_values(['method', 'organism']), x='organism, #reactions', y='time', hue='method',
               kind='bar', height=8, aspect=1.7)
sns.move_legend(g, loc="upper left", bbox_to_anchor=(-0.1, 1.2))
g.figure.suptitle("Runtime per Organism (FBApro batched, others single-sample)", y=1.05)
plt.yscale('log')
plt.ylabel("Time (seconds)")
plt.tight_layout()
filename = "timing_methods_different_models.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single organism detail (human_1 / Recon1)

# %%
sns.set(style="darkgrid", font_scale=2)

filter_mask = ~runtimes_df["method"].str.contains("FBApro|_setup", regex=True) | (runtimes_df["batch"] == n_samples_per_graph)
filtered = runtimes_df.loc[filter_mask].copy()
filtered = filtered.loc[~filtered['method'].str.contains('setup')]
filtered = filtered.loc[filtered['organism'] == 'human_1']
filtered = set_method_order(filtered)
runtimes_df['organism, #reactions'] = runtimes_df['organism'].str.replace("human_1", "Recon1") + ", " + runtimes_df['reactions'].astype(str)

g = sns.catplot(data=filtered.sort_values(['method', 'organism']), x='organism, #reactions', y='time', hue='method',
           kind='bar', height=8, aspect=1.7)
sns.move_legend(g, loc="upper left", bbox_to_anchor=(0.1, 0.95))
g.figure.suptitle("Runtime — Recon1 Model", y=1.02)
plt.xlabel("")
plt.ylabel("Time (seconds)")
g.set(xticklabels=[])
plt.yscale('log')
plt.tight_layout()
filename = "timing_methods.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Setup time — single organism (human_1, CPU)

# %%
sns.set(style="darkgrid", font_scale=2)

data = runtimes_df.loc[runtimes_df["method"].str.contains('setup')].copy()
data['method'] = data['method'].str.replace("_setup", "")
data = set_method_order(data)

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=data, x='device', y='time', hue='method', ax=ax)
ax.set_title("Setup Time — Recon1")
ax.set_xlabel("")
ax.set_ylabel("Time (seconds)")
ax.set(xticklabels=[])
plt.yscale('log')
plt.legend()
plt.tight_layout()
filename = "timing_setup_recon1.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %%
sns.set(style="darkgrid", font_scale=2)

data = runtimes_df.loc[runtimes_df["method"].str.contains('setup')].copy()
data['method'] = data['method'].str.replace("_setup", "")
data = set_method_order(data)
data = data.loc[(data['organism'] == 'human_1') & (data['device'] == 'GPU')]

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=data, x='device', y='time', hue='method', ax=ax)
ax.set_title("Setup Time — Recon1 (CPU)")
ax.set_xlabel("")
ax.set_ylabel("Time (seconds)")
ax.set(xticklabels=[])
plt.yscale('log')
plt.legend()
plt.tight_layout()
filename = "timing_setup_gpu_recon1.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Setup time — all organisms

# %%
filtered = runtimes_df.sort_values('reactions').loc[runtimes_df["method"].str.contains('setup')].copy()
filtered['method'] = filtered['method'].str.replace("_setup", "")
filtered = set_method_order(filtered)

fig, ax = plt.subplots(figsize=(14, 7))
sns.barplot(data=filtered, x='organism, #reactions', y='time', hue='method', ax=ax)
ax.set_title("Setup Time by Organism")
ax.set_ylabel("Time (seconds)")
plt.yscale('log')
plt.legend()
plt.tight_layout()
filename = "timing_setup_multi_organisms.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Test amortized runtime of FBApro variants as function of number of samples

# %% [markdown]
# ### Regenerate bounds (for GPU amortization test)

# %%
# Bounds are already computed above; this cell is kept for compatibility.
# If you need to recompute with different settings, do so here.

# %%
# %%time
n_timeit_nonsetup_repeats = 50
n_samples_per_graph_amortized = n_samples_per_graph  # use same sample count

assert torch.cuda.is_available(), "GPU is required for amortized timing comparison. No CUDA device found."
gpu_device = torch.device('cuda')

amortized_records = []
for i in range(len(models)):
    print("model {}, size {}".format(i, len(models[i].reactions)))
    model = models[i]
    organism_name = model_name_to_organism[model.id]
    n_rxns = len(model.reactions)
    obj_coefs = {rxn.id: rxn.objective_coefficient for rxn in model.reactions if rxn.objective_coefficient != 0}
    print(obj_coefs)
    print([r.id for r in model.reactions if 'biomass' in r.id.lower()])
    if len(obj_coefs) == 0:
        growth_related_reactions = [r.id for r in model.reactions if 'biomass' in r.id.lower()]
        assert len(growth_related_reactions) == 1
        obj_coefs = {growth_related_reactions[0]: 1}
    assert len(obj_coefs) == 1 and all([v == 1 for k, v in obj_coefs.items()])
    objective_reaction_ids = obj_coefs.popitem()[0]

    A = As[i]
    basis = ss_bases[i]
    known_mask = known_masks[i]
    unknown_mask = unknown_masks[i]
    X = Xs[i].to(dtype=torch.double, device=gpu_device)
    y = ys[i].to(dtype=torch.double, device=gpu_device)
    l = ls[i].to(dtype=torch.double, device=gpu_device)
    u = us[i].to(dtype=torch.double, device=gpu_device)

    with model:
        for method in [FBApro]:  # amortization only relevant for FBApro
            partial_fixed_iterators = itertools.product([False, True], [False, True])
            for (is_partial, is_fixed) in partial_fixed_iterators:
                unknown_indices = [q for q in range(len(unknown_mask)) if unknown_mask[q]] if is_partial else []
                measured_indices = [q for q in range(len(known_mask)) if known_mask[q]] if is_fixed else []
                cur_records = []

                proj_tmp = method(model=model, stoichiometric_matrix=A,
                                  unknown_indices=unknown_indices, measured_indices=measured_indices,
                                  steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                                  device=gpu_device, objective_id=objective_reaction_ids)
                name = normalize_method_name(str(proj_tmp))
                del proj_tmp
                print("  ", name)

                for samples_frac in np.linspace(start=0, stop=1, num=100)[1:]:
                    n_samples = int(math.floor(n_samples_per_graph_amortized * samples_frac))
                    if n_samples == 0:
                        continue
                    random_samples = np.random.randint(0, X.shape[0], size=(n_samples,))

                    def setup_and_run_func(method, device, x, l, u):
                        proj = method(model=model, stoichiometric_matrix=A,
                          unknown_indices=unknown_indices, measured_indices=measured_indices,
                          steady_state_basis_matrix=basis, l_bounds=l, u_bounds=u,
                          device=device, objective_id=objective_reaction_ids)
                        proj.forward(x, l, u)

                    timeit_results = timeit.repeat(
                        functools.partial(setup_and_run_func, method, torch.device('cuda'), X[random_samples, :],
                                          l[random_samples], u[random_samples]),
                        number=1, repeat=n_timeit_nonsetup_repeats)
                    for t in timeit_results:
                        cur_records.append({'organism': organism_name, 'reactions': n_rxns,
                                            'method': name, 'batch': n_samples, 'time': t / n_samples})

                amortized_records.extend(cur_records)

    save_checkpoint({'amortized_records': amortized_records},
                    os.path.join(caching_dir, 'amortized_timing_checkpoint.pkl'))

amortized_runtimes_df = pd.DataFrame(amortized_records)
# Out:
# model 0, size 95
# {'BIOMASS_Ecoli_core_w_GAM': 1.0}
# ['BIOMASS_Ecoli_core_w_GAM']
#    FBAproBasic
# /home/abronner/FBApro/projection_methods.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer('stoic', torch.tensor(stoichiometric_matrix, device=device, dtype=dtype),
#    FBAproFixed
# ...
# Input - abs min: 0.00e+00, abs max: 6.14e-01, abs mean: 2.16e-02
# output - abs min: 3.96e-16, abs max: 5.22e-01, abs mean: 7.16e-02
# S * output - abs min: 2.57e-16, abs max: 4.58e-01, abs mean: 9.56e-02
# Suppressing further warnings.
# ...
# Input - abs min: 0.00e+00, abs max: 6.14e-01, abs mean: 2.16e-02
# output - abs min: 3.96e-16, abs max: 5.22e-01, abs mean: 7.16e-02
# S * output - abs min: 2.57e-16, abs max: 4.58e-01, abs mean: 9.56e-02
# Suppressing further warnings.
# ...

# %% [markdown]
# ### Save amortized results

# %%
amortized_runtimes_df.to_csv(os.path.join(export_path, "figure_recreation_data", "amortized_runtimes_df"))

# %% [markdown]
# ### Amortized runtime vs batch size (line plot)

# %%
sns.set(style="darkgrid", font_scale=2)

filtered = amortized_runtimes_df.copy()
filtered = set_method_order(filtered)

fig, ax = plt.subplots(figsize=(12, 7))
sns.lineplot(data=filtered, x='batch', y='time', hue='method', ax=ax)
ax.set_title("Amortized Per-Sample Runtime vs Batch Size (FBApro variants)")
ax.set_xlabel("Batch Size")
ax.set_ylabel("Time per Sample (seconds)")
plt.yscale('log')
plt.legend()
plt.tight_layout()
filename = "timing_per_batch_size.png"
plt.savefig(os.path.join(export_path, filename), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Amortized runtime vs batch size (bar plot)

# %%
filtered = amortized_runtimes_df.copy()
filtered = set_method_order(filtered)

fig, ax = plt.subplots(figsize=(20, 8))
sns.barplot(data=filtered, x='batch', y='time', hue='method', ax=ax)
ax.set_title("Amortized Per-Sample Runtime by Batch Size (FBApro variants)")
ax.set_xlabel("Batch Size")
ax.set_ylabel("Time per Sample (seconds)")
plt.tight_layout()
plt.show()
